# %%
import pandas as pd
import numpy as np
np.random.seed(0)

# %%
def reload_data(name='nobel_winners_dirty.json'):
    df = pd.read_json(open(name))
    return df

# %%
df = reload_data()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1052 entries, 0 to 1051
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   born_in         1052 non-null   object
#  1   category        1052 non-null   object
#  2   country         1052 non-null   object
#  3   date_of_birth   1044 non-null   object
#  4   date_of_death   1044 non-null   object
#  5   gender          1040 non-null   object
#  6   link            1052 non-null   object
#  7   name            1052 non-null   object
#  8   place_of_birth  1044 non-null   object
#  9   place_of_death  1044 non-null   object
#  10  text            1052 non-null   object
#  11  year            1052 non-null   int64
# dtypes: int64(1), object(11)
# memory usage: 98.8+ KB

# %%
df.describe()
# Out:
#               year
# count  1052.000000
# mean   1968.729087
# std      33.155829
# min    1809.000000
# 25%    1947.000000
# 50%    1975.000000
# 75%    1996.000000
# max    2014.000000

# %%
df.describe(include=['object'])
# Out:
#        born_in                category        country    date_of_birth  \
# count     1052                    1052           1052             1044
# unique      40                       7             59              853
# top             Physiology or Medicine  United States  7 November 1867
# freq       910                     250            350                4
#
#        date_of_death gender                                         link  \
# count           1044   1040                                         1052
# unique           563      2                                          893
# top                    male  http://en.wikipedia.org/wiki/Michael_Levitt
# freq             362    982                                            4
#
#                   name place_of_birth place_of_death  \
# count             1052           1044           1044
# unique             998            735            410
# top     Shimon Peres *
# freq                 2             29            409
#
#                                                      text
# count                                                1052
# unique                                               1043
# top     Sydney Brenner ,  born in South Africa , Physi...
# freq                                                    2

# %%
df.head()
# Out:
#                   born_in                category    country   date_of_birth  \
# 0                          Physiology or Medicine  Argentina  8 October 1927
# 1  Bosnia and Herzegovina              Literature             9 October 1892
# 2  Bosnia and Herzegovina               Chemistry              July 23, 1906
# 3                                           Peace    Belgium            None
# 4                                           Peace    Belgium    26 July 1829
#
#     date_of_death gender                                               link  \
# 0   24 March 2002   male   http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
# 1   13 March 1975   male            http://en.wikipedia.org/wiki/Ivo_Andric
# 2      1998-01-07   male       http://en.wikipedia.org/wiki/Vladimir_Prelog
# 3            None   None  http://en.wikipedia.org/wiki/Institut_de_Droit...
# 4  6 October 1912   male  http://en.wikipedia.org/wiki/Auguste_Marie_Fra...
#
#                               name  \
# 0                   César Milstein
# 1                     Ivo Andric *
# 2                Vladimir Prelog *
# 3  Institut de Droit International
# 4                Auguste Beernaert
#
#                                       place_of_birth  \
# 0                          Bahía Blanca ,  Argentina
# 1  Dolac (village near Travnik), Austria-Hungary ...
# 2  Sarajevo ,  Bosnia and Herzegovina , then part...
# 3                                               None
# 4             Ostend ,  Netherlands  (now  Belgium )
#
#                                       place_of_death  \
# 0                                Cambridge , England
# 1  Belgrade, SR Serbia, SFR Yugoslavia (present-d...
# 2                              Zürich ,  Switzerland
# 3                                               None
# 4                             Lucerne ,  Switzerland
#
#                                                 text  year
# 0      César Milstein , Physiology or Medicine, 1984  1984
# 1  Ivo Andric *,  born in then  Austria–Hungary ,...  1961
# 2  Vladimir Prelog *,  born in then  Austria–Hung...  1975
# 3      Institut de Droit International , Peace, 1904  1904
# 4                    Auguste Beernaert , Peace, 1909  1909

# %%
df = df.set_index('name')
df.head(2)
# Out:
#                                born_in                category    country  \
# name
# César Milstein                          Physiology or Medicine  Argentina
# Ivo Andric *    Bosnia and Herzegovina              Literature
#
#                  date_of_birth  date_of_death gender  \
# name
# César Milstein  8 October 1927  24 March 2002   male
# Ivo Andric *    9 October 1892  13 March 1975   male
#
#                                                             link  \
# name
# César Milstein  http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
# Ivo Andric *             http://en.wikipedia.org/wiki/Ivo_Andric
#
#                                                    place_of_birth  \
# name
# César Milstein                          Bahía Blanca ,  Argentina
# Ivo Andric *    Dolac (village near Travnik), Austria-Hungary ...
#
#                                                    place_of_death  \
# name
# César Milstein                                Cambridge , England
# Ivo Andric *    Belgrade, SR Serbia, SFR Yugoslavia (present-d...
#
#                                                              text  year
# name
# César Milstein      César Milstein , Physiology or Medicine, 1984  1984
# Ivo Andric *    Ivo Andric *,  born in then  Austria–Hungary ,...  1961

# %%
df.reset_index(inplace=True)
df.head(2)
# Out:
#              name                 born_in                category    country  \
# 0  César Milstein                          Physiology or Medicine  Argentina
# 1    Ivo Andric *  Bosnia and Herzegovina              Literature
#
#     date_of_birth  date_of_death gender  \
# 0  8 October 1927  24 March 2002   male
# 1  9 October 1892  13 March 1975   male
#
#                                                link  \
# 0  http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
# 1           http://en.wikipedia.org/wiki/Ivo_Andric
#
#                                       place_of_birth  \
# 0                          Bahía Blanca ,  Argentina
# 1  Dolac (village near Travnik), Austria-Hungary ...
#
#                                       place_of_death  \
# 0                                Cambridge , England
# 1  Belgrade, SR Serbia, SFR Yugoslavia (present-d...
#
#                                                 text  year
# 0      César Milstein , Physiology or Medicine, 1984  1984
# 1  Ivo Andric *,  born in then  Austria–Hungary ,...  1961

# %%
bi_col = df.born_in
bi_col
# Out:
# 0
# 1       Bosnia and Herzegovina
# 2       Bosnia and Herzegovina
# 3
# 4
#                  ...
# 1047
# 1048
# 1049
# 1050
# 1051
# Name: born_in, Length: 1052, dtype: object

# %%
type(bi_col)
# Out:
# pandas.core.series.Series

# %%
df.iloc[0]
# Out:
# name                                                César Milstein
# born_in
# category                                    Physiology or Medicine
# country                                                  Argentina
# date_of_birth                                       8 October 1927
# date_of_death                                        24 March 2002
# gender                                                        male
# link              http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
# place_of_birth                           Bahía Blanca ,  Argentina
# place_of_death                                 Cambridge , England
# text                 César Milstein , Physiology or Medicine, 1984
# year                                                          1984
# Name: 0, dtype: object

# %%
df.set_index('name',inplace=True)
df.loc['Albert Einstein']
# Out:
#                 born_in category      country date_of_birth date_of_death  \
# name
# Albert Einstein          Physics  Switzerland    1879-03-14    1955-04-18
# Albert Einstein          Physics      Germany    1879-03-14    1955-04-18
#
#                 gender                                          link  \
# name
# Albert Einstein   male  http://en.wikipedia.org/wiki/Albert_Einstein
# Albert Einstein   male  http://en.wikipedia.org/wiki/Albert_Einstein
#
#                                            place_of_birth  \
# name
# Albert Einstein  Ulm ,  Baden-Württemberg , German Empire
# Albert Einstein  Ulm ,  Baden-Württemberg , German Empire
#
#                                place_of_death  \
# name
# Albert Einstein  Princeton, New Jersey , U.S.
# Albert Einstein  Princeton, New Jersey , U.S.
#
#                                                               text  year
# name
# Albert Einstein  Albert Einstein ,  born in Germany , Physics, ...  1921
# Albert Einstein                    Albert Einstein , Physics, 1921  1921

# %%
df[0:10]
# Out:
#                                                 born_in  \
# name
# César Milstein
# Ivo Andric *                     Bosnia and Herzegovina
# Vladimir Prelog *                Bosnia and Herzegovina
# Institut de Droit International
# Auguste Beernaert
# Maurice Maeterlinck
# Henri La Fontaine
# Jules Bordet
# Corneille Heymans
# Georges Pire
#
#                                                category    country  \
# name
# César Milstein                   Physiology or Medicine  Argentina
# Ivo Andric *                                 Literature
# Vladimir Prelog *                             Chemistry
# Institut de Droit International                   Peace    Belgium
# Auguste Beernaert                                 Peace    Belgium
# Maurice Maeterlinck                          Literature    Belgium
# Henri La Fontaine                                 Peace    Belgium
# Jules Bordet                     Physiology or Medicine    Belgium
# Corneille Heymans                Physiology or Medicine    Belgium
# Georges Pire                                      Peace    Belgium
#
#                                   date_of_birth   date_of_death gender  \
# name
# César Milstein                   8 October 1927   24 March 2002   male
# Ivo Andric *                     9 October 1892   13 March 1975   male
# Vladimir Prelog *                 July 23, 1906      1998-01-07   male
# Institut de Droit International            None            None   None
# Auguste Beernaert                  26 July 1829  6 October 1912   male
# Maurice Maeterlinck              29 August 1862      6 May 1949   male
# Henri La Fontaine                 22 April 1854     14 May 1943   male
# Jules Bordet                       13 June 1870    6 April 1961   male
# Corneille Heymans                 28 March 1892    18 July 1968   male
# Georges Pire                         1910-02-10      1969-01-30   male
#
#                                                                               link  \
# name
# César Milstein                    http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
# Ivo Andric *                               http://en.wikipedia.org/wiki/Ivo_Andric
# Vladimir Prelog *                     http://en.wikipedia.org/wiki/Vladimir_Prelog
# Institut de Droit International  http://en.wikipedia.org/wiki/Institut_de_Droit...
# Auguste Beernaert                http://en.wikipedia.org/wiki/Auguste_Marie_Fra...
# Maurice Maeterlinck               http://en.wikipedia.org/wiki/Maurice_Maeterlinck
# Henri La Fontaine                   http://en.wikipedia.org/wiki/Henri_La_Fontaine
# Jules Bordet                             http://en.wikipedia.org/wiki/Jules_Bordet
# Corneille Heymans                   http://en.wikipedia.org/wiki/Corneille_Heymans
# Georges Pire                             http://en.wikipedia.org/wiki/Georges_Pire
#
#                                                                     place_of_birth  \
# name
# César Milstein                                           Bahía Blanca ,  Argentina
# Ivo Andric *                     Dolac (village near Travnik), Austria-Hungary ...
# Vladimir Prelog *                Sarajevo ,  Bosnia and Herzegovina , then part...
# Institut de Droit International                                               None
# Auguste Beernaert                           Ostend ,  Netherlands  (now  Belgium )
# Maurice Maeterlinck                                               Ghent ,  Belgium
# Henri La Fontaine                                                         Brussels
# Jules Bordet                                                     Soignies, Belgium
# Corneille Heymans                                                Ghent ,  Flanders
# Georges Pire                                                     Dinant ,  Belgium
#
#                                                                     place_of_death  \
# name
# César Milstein                                                 Cambridge , England
# Ivo Andric *                     Belgrade, SR Serbia, SFR Yugoslavia (present-d...
# Vladimir Prelog *                                            Zürich ,  Switzerland
# Institut de Droit International                                               None
# Auguste Beernaert                                           Lucerne ,  Switzerland
# Maurice Maeterlinck                                                 Nice ,  France
# Henri La Fontaine                                                          Belgium
# Jules Bordet
# Corneille Heymans                                               Knokke ,  Flanders
# Georges Pire                                                      Leuven , Belgium
#
#                                                                               text  \
# name
# César Milstein                       César Milstein , Physiology or Medicine, 1984
# Ivo Andric *                     Ivo Andric *,  born in then  Austria–Hungary ,...
# Vladimir Prelog *                Vladimir Prelog *,  born in then  Austria–Hung...
# Institut de Droit International      Institut de Droit International , Peace, 1904
# Auguste Beernaert                                  Auguste Beernaert , Peace, 1909
# Maurice Maeterlinck                         Maurice Maeterlinck , Literature, 1911
# Henri La Fontaine                                  Henri La Fontaine , Peace, 1913
# Jules Bordet                           Jules Bordet , Physiology or Medicine, 1919
# Corneille Heymans                 Corneille Heymans , Physiology or Medicine, 1938
# Georges Pire                                            Georges Pire , Peace, 1958
#
#                                  year
# name
# César Milstein                   1984
# Ivo Andric *                     1961
# Vladimir Prelog *                1975
# Institut de Droit International  1904
# Auguste Beernaert                1909
# Maurice Maeterlinck              1911
# Henri La Fontaine                1913
# Jules Bordet                     1919
# Corneille Heymans                1938
# Georges Pire                     1958

# %%
mask =df.year > 2000

# %%
mask
# Out:
# name
# César Milstein                     False
# Ivo Andric *                       False
# Vladimir Prelog *                  False
# Institut de Droit International    False
# Auguste Beernaert                  False
#                                    ...
# Brian P. Schmidt                    True
# Carlos Saavedra Lamas              False
# Bernardo Houssay                   False
# Luis Federico Leloir               False
# Adolfo Pérez Esquivel              False
# Name: year, Length: 1052, dtype: bool

# %%
mask = df.year >2000
winners_since_2000 =df[mask]
winners_since_2000.count()
# Out:
# born_in           202
# category          202
# country           202
# date_of_birth     201
# date_of_death     201
# gender            200
# link              202
# place_of_birth    201
# place_of_death    201
# text              202
# year              202
# dtype: int64

# %%
winners_since_2000.head()
# Out:
#                           born_in                category  country  \
# name
# François Englert                                  Physics  Belgium
# Christopher A. Pissarides                       Economics   Cyprus
# Kofi Annan                                          Peace    Ghana
# Riccardo Giacconi *         Italy                 Physics
# Mario Capecchi *            Italy  Physiology or Medicine
#
#                              date_of_birth date_of_death gender  \
# name
# François Englert           6 November 1932                 male
# Christopher A. Pissarides       1948-02-20                 male
# Kofi Annan                    8 April 1938                 male
# Riccardo Giacconi *        October 6, 1931                 male
# Mario Capecchi *            6 October 1937                 male
#
#                                                                         link  \
# name
# François Englert           http://en.wikipedia.org/wiki/Fran%C3%A7ois_Eng...
# Christopher A. Pissarides  http://en.wikipedia.org/wiki/Christopher_A._Pi...
# Kofi Annan                           http://en.wikipedia.org/wiki/Kofi_Annan
# Riccardo Giacconi *           http://en.wikipedia.org/wiki/Riccardo_Giacconi
# Mario Capecchi *                 http://en.wikipedia.org/wiki/Mario_Capecchi
#
#                                              place_of_birth place_of_death  \
# name
# François Englert           Etterbeek ,  Brussels ,  Belgium
# Christopher A. Pissarides                   Nicosia, Cyprus
# Kofi Annan                                   Kumasi , Ghana
# Riccardo Giacconi *                          Genoa ,  Italy
# Mario Capecchi *                            Verona ,  Italy
#
#                                                                      text  \
# name
# François Englert                         François Englert , Physics, 2013
# Christopher A. Pissarides     Christopher A. Pissarides , Economics, 2010
# Kofi Annan                                       Kofi Annan , Peace, 2001
# Riccardo Giacconi *                    Riccardo Giacconi *, Physics, 2002
# Mario Capecchi *           Mario Capecchi *, Physiology or Medicine, 2007
#
#                            year
# name
# François Englert           2013
# Christopher A. Pissarides  2010
# Kofi Annan                 2001
# Riccardo Giacconi *        2002
# Mario Capecchi *           2007

# %%
winners_since_2000 =df[df.year >2000]

# %%
winners_since_2000.head()
# Out:
#                           born_in                category  country  \
# name
# François Englert                                  Physics  Belgium
# Christopher A. Pissarides                       Economics   Cyprus
# Kofi Annan                                          Peace    Ghana
# Riccardo Giacconi *         Italy                 Physics
# Mario Capecchi *            Italy  Physiology or Medicine
#
#                              date_of_birth date_of_death gender  \
# name
# François Englert           6 November 1932                 male
# Christopher A. Pissarides       1948-02-20                 male
# Kofi Annan                    8 April 1938                 male
# Riccardo Giacconi *        October 6, 1931                 male
# Mario Capecchi *            6 October 1937                 male
#
#                                                                         link  \
# name
# François Englert           http://en.wikipedia.org/wiki/Fran%C3%A7ois_Eng...
# Christopher A. Pissarides  http://en.wikipedia.org/wiki/Christopher_A._Pi...
# Kofi Annan                           http://en.wikipedia.org/wiki/Kofi_Annan
# Riccardo Giacconi *           http://en.wikipedia.org/wiki/Riccardo_Giacconi
# Mario Capecchi *                 http://en.wikipedia.org/wiki/Mario_Capecchi
#
#                                              place_of_birth place_of_death  \
# name
# François Englert           Etterbeek ,  Brussels ,  Belgium
# Christopher A. Pissarides                   Nicosia, Cyprus
# Kofi Annan                                   Kumasi , Ghana
# Riccardo Giacconi *                          Genoa ,  Italy
# Mario Capecchi *                            Verona ,  Italy
#
#                                                                      text  \
# name
# François Englert                         François Englert , Physics, 2013
# Christopher A. Pissarides     Christopher A. Pissarides , Economics, 2010
# Kofi Annan                                       Kofi Annan , Peace, 2001
# Riccardo Giacconi *                    Riccardo Giacconi *, Physics, 2002
# Mario Capecchi *           Mario Capecchi *, Physiology or Medicine, 2007
#
#                            year
# name
# François Englert           2013
# Christopher A. Pissarides  2010
# Kofi Annan                 2001
# Riccardo Giacconi *        2002
# Mario Capecchi *           2007

# %%
df.born_in.describe()
# Out:
# count     1052
# unique      40
# top
# freq       910
# Name: born_in, dtype: object

# %%
set(df.born_in.apply(type))
# Out:
# {str}

# %%
bi_col.replace('',np.nan,inplace=True)
bi_col
# Out:
# 0                          NaN
# 1       Bosnia and Herzegovina
# 2       Bosnia and Herzegovina
# 3                          NaN
# 4                          NaN
#                  ...
# 1047                       NaN
# 1048                       NaN
# 1049                       NaN
# 1050                       NaN
# 1051                       NaN
# Name: born_in, Length: 1052, dtype: object

# %%
bi_col.count()
# Out:
# 142

# %%
df.replace('',np.nan,inplace=True)

# %%
df.head()
# Out:
#                                                 born_in  \
# name
# César Milstein                                      NaN
# Ivo Andric *                     Bosnia and Herzegovina
# Vladimir Prelog *                Bosnia and Herzegovina
# Institut de Droit International                     NaN
# Auguste Beernaert                                   NaN
#
#                                                category    country  \
# name
# César Milstein                   Physiology or Medicine  Argentina
# Ivo Andric *                                 Literature        NaN
# Vladimir Prelog *                             Chemistry        NaN
# Institut de Droit International                   Peace    Belgium
# Auguste Beernaert                                 Peace    Belgium
#
#                                   date_of_birth   date_of_death gender  \
# name
# César Milstein                   8 October 1927   24 March 2002   male
# Ivo Andric *                     9 October 1892   13 March 1975   male
# Vladimir Prelog *                 July 23, 1906      1998-01-07   male
# Institut de Droit International            None            None   None
# Auguste Beernaert                  26 July 1829  6 October 1912   male
#
#                                                                               link  \
# name
# César Milstein                    http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
# Ivo Andric *                               http://en.wikipedia.org/wiki/Ivo_Andric
# Vladimir Prelog *                     http://en.wikipedia.org/wiki/Vladimir_Prelog
# Institut de Droit International  http://en.wikipedia.org/wiki/Institut_de_Droit...
# Auguste Beernaert                http://en.wikipedia.org/wiki/Auguste_Marie_Fra...
#
#                                                                     place_of_birth  \
# name
# César Milstein                                           Bahía Blanca ,  Argentina
# Ivo Andric *                     Dolac (village near Travnik), Austria-Hungary ...
# Vladimir Prelog *                Sarajevo ,  Bosnia and Herzegovina , then part...
# Institut de Droit International                                               None
# Auguste Beernaert                           Ostend ,  Netherlands  (now  Belgium )
#
#                                                                     place_of_death  \
# name
# César Milstein                                                 Cambridge , England
# Ivo Andric *                     Belgrade, SR Serbia, SFR Yugoslavia (present-d...
# Vladimir Prelog *                                            Zürich ,  Switzerland
# Institut de Droit International                                               None
# Auguste Beernaert                                           Lucerne ,  Switzerland
#
#                                                                               text  \
# name
# César Milstein                       César Milstein , Physiology or Medicine, 1984
# Ivo Andric *                     Ivo Andric *,  born in then  Austria–Hungary ,...
# Vladimir Prelog *                Vladimir Prelog *,  born in then  Austria–Hung...
# Institut de Droit International      Institut de Droit International , Peace, 1904
# Auguste Beernaert                                  Auguste Beernaert , Peace, 1909
#
#                                  year
# name
# César Milstein                   1984
# Ivo Andric *                     1961
# Vladimir Prelog *                1975
# Institut de Droit International  1904
# Auguste Beernaert                1909

# %%
df.gender.str.contains('male')
# Out:
# name
# César Milstein                     True
# Ivo Andric *                       True
# Vladimir Prelog *                  True
# Institut de Droit International    None
# Auguste Beernaert                  True
#                                    ...
# Brian P. Schmidt                   True
# Carlos Saavedra Lamas              True
# Bernardo Houssay                   True
# Luis Federico Leloir               True
# Adolfo Pérez Esquivel              True
# Name: gender, Length: 1052, dtype: object

# %%
df[0:10]
# Out:
#                                                 born_in  \
# name
# César Milstein                                      NaN
# Ivo Andric *                     Bosnia and Herzegovina
# Vladimir Prelog *                Bosnia and Herzegovina
# Institut de Droit International                     NaN
# Auguste Beernaert                                   NaN
# Maurice Maeterlinck                                 NaN
# Henri La Fontaine                                   NaN
# Jules Bordet                                        NaN
# Corneille Heymans                                   NaN
# Georges Pire                                        NaN
#
#                                                category    country  \
# name
# César Milstein                   Physiology or Medicine  Argentina
# Ivo Andric *                                 Literature        NaN
# Vladimir Prelog *                             Chemistry        NaN
# Institut de Droit International                   Peace    Belgium
# Auguste Beernaert                                 Peace    Belgium
# Maurice Maeterlinck                          Literature    Belgium
# Henri La Fontaine                                 Peace    Belgium
# Jules Bordet                     Physiology or Medicine    Belgium
# Corneille Heymans                Physiology or Medicine    Belgium
# Georges Pire                                      Peace    Belgium
#
#                                   date_of_birth   date_of_death gender  \
# name
# César Milstein                   8 October 1927   24 March 2002   male
# Ivo Andric *                     9 October 1892   13 March 1975   male
# Vladimir Prelog *                 July 23, 1906      1998-01-07   male
# Institut de Droit International            None            None   None
# Auguste Beernaert                  26 July 1829  6 October 1912   male
# Maurice Maeterlinck              29 August 1862      6 May 1949   male
# Henri La Fontaine                 22 April 1854     14 May 1943   male
# Jules Bordet                       13 June 1870    6 April 1961   male
# Corneille Heymans                 28 March 1892    18 July 1968   male
# Georges Pire                         1910-02-10      1969-01-30   male
#
#                                                                               link  \
# name
# César Milstein                    http://en.wikipedia.org/wiki/C%C3%A9sar_Milstein
# Ivo Andric *                               http://en.wikipedia.org/wiki/Ivo_Andric
# Vladimir Prelog *                     http://en.wikipedia.org/wiki/Vladimir_Prelog
# Institut de Droit International  http://en.wikipedia.org/wiki/Institut_de_Droit...
# Auguste Beernaert                http://en.wikipedia.org/wiki/Auguste_Marie_Fra...
# Maurice Maeterlinck               http://en.wikipedia.org/wiki/Maurice_Maeterlinck
# Henri La Fontaine                   http://en.wikipedia.org/wiki/Henri_La_Fontaine
# Jules Bordet                             http://en.wikipedia.org/wiki/Jules_Bordet
# Corneille Heymans                   http://en.wikipedia.org/wiki/Corneille_Heymans
# Georges Pire                             http://en.wikipedia.org/wiki/Georges_Pire
#
#                                                                     place_of_birth  \
# name
# César Milstein                                           Bahía Blanca ,  Argentina
# Ivo Andric *                     Dolac (village near Travnik), Austria-Hungary ...
# Vladimir Prelog *                Sarajevo ,  Bosnia and Herzegovina , then part...
# Institut de Droit International                                               None
# Auguste Beernaert                           Ostend ,  Netherlands  (now  Belgium )
# Maurice Maeterlinck                                               Ghent ,  Belgium
# Henri La Fontaine                                                         Brussels
# Jules Bordet                                                     Soignies, Belgium
# Corneille Heymans                                                Ghent ,  Flanders
# Georges Pire                                                     Dinant ,  Belgium
#
#                                                                     place_of_death  \
# name
# César Milstein                                                 Cambridge , England
# Ivo Andric *                     Belgrade, SR Serbia, SFR Yugoslavia (present-d...
# Vladimir Prelog *                                            Zürich ,  Switzerland
# Institut de Droit International                                               None
# Auguste Beernaert                                           Lucerne ,  Switzerland
# Maurice Maeterlinck                                                 Nice ,  France
# Henri La Fontaine                                                          Belgium
# Jules Bordet                                                                   NaN
# Corneille Heymans                                               Knokke ,  Flanders
# Georges Pire                                                      Leuven , Belgium
#
#                                                                               text  \
# name
# César Milstein                       César Milstein , Physiology or Medicine, 1984
# Ivo Andric *                     Ivo Andric *,  born in then  Austria–Hungary ,...
# Vladimir Prelog *                Vladimir Prelog *,  born in then  Austria–Hung...
# Institut de Droit International      Institut de Droit International , Peace, 1904
# Auguste Beernaert                                  Auguste Beernaert , Peace, 1909
# Maurice Maeterlinck                         Maurice Maeterlinck , Literature, 1911
# Henri La Fontaine                                  Henri La Fontaine , Peace, 1913
# Jules Bordet                           Jules Bordet , Physiology or Medicine, 1919
# Corneille Heymans                 Corneille Heymans , Physiology or Medicine, 1938
# Georges Pire                                            Georges Pire , Peace, 1958
#
#                                  year
# name
# César Milstein                   1984
# Ivo Andric *                     1961
# Vladimir Prelog *                1975
# Institut de Droit International  1904
# Auguste Beernaert                1909
# Maurice Maeterlinck              1911
# Henri La Fontaine                1913
# Jules Bordet                     1919
# Corneille Heymans                1938
# Georges Pire                     1958
