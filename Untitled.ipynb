# %%
from bs4 import BeautifulSoup
import requests

# %%
def get_nobel_winners(table):
    cols = get_column_titles(table)
    winners = []
    for row in table.select('tr')[1:-2]:
        year = str(row.select_one('td').text)
        for i, td in enumerate(row.select('td')[1:]):
            for winner in td.select('a'):
                href = winner.attrs['href']
                if not href.startswith('#endnote'):
                    winners.append({'year': year,
                                    'category': cols[i]['name'],
                                    'name': winner.text,
                                    'link': winner['href']})
    return winners

# %%
def get_column_titles(table):
    cols = []
    for th in table.select_one('tr').select('th')[1:]:
        link = th.select_one('a')
        if link:
            cols.append({'name': link.text, 'href': link.attrs['href']})
        else:
            cols.append({'name': th.text, 'href': None})
    return cols

# %%
BASE_URL = "http://en.wikipedia.org"
HEADERS = {'User-Agent': 'Mozilla/5.0'}

# %%
def get_Nobel_soup():
    response = requests.get(
        BASE_URL + '/wiki/List_of_Nobel_laureates', headers=HEADERS)
    return BeautifulSoup(response.content, "lxml")

# %%
soup = get_Nobel_soup()
table = soup.select_one('table.sortable.wikitable')
d = get_nobel_winners(table)
print(str(d).encode('UTF-8'))
# Out:
# b'[{\'year\': \'1901\\n\', \'category\': \'Physics\', \'name\': \'Wilhelm R\xc3\xb6ntgen\', \'link\': \'/wiki/Wilhelm_R%C3%B6ntgen\'}, {\'year\': \'1901\\n\', \'category\': \'Chemistry\', \'name\': "Jacobus Henricus van \'t Hoff", \'link\': \'/wiki/Jacobus_Henricus_van_%27t_Hoff\'}, {\'year\': \'1901\\n\', \'category\': \'Physiologyor Medicine\', \'name\': \'Emil Adolf von Behring\', \'link\': \'/wiki/Emil_Adolf_von_Behring\'}, {\'year\': \'1901\\n\', \'category\': \'Literature\', \'name\': \'Sully Prudhomme\', \'link\': \'/wiki/Sully_Prudhomme\'}, {\'year\': \'1901\\n\', \'category\': \'Peace\', \'name\': \'Henry Dunant\', \'link\': \'/wiki/Henry_Dunant\'}, {\'year\': \'1901\\n\', \'category\': \'Peace\', \'name\': \'Fr\xc3\xa9d\xc3\xa9ric Passy\', \'link\': \'/wiki/Fr%C3%A9d%C3%A9ric_Passy\'}, {\'year\': \'1902\\n\', \'category\': \'Physics\', \'name\': \'Hendrik Lorentz\', \'link\': \'/wiki/Hendrik_Lorentz\'}, {\'year\': \'1902\\n\', \'category\': \'Physics\', \'name\': \'Pieter Zeeman\', \'link\': \'/wiki/Pieter_Zeeman\'}, {\'year\': \'1902\\n\', \'category\': \'Chemistry\', \'name\': \'Hermann Emil Fischer\', \'link\': \'/wiki/Hermann_Emil_Fischer\'}, {\'year\': \'1902\\n\', \'category\': \'Physiologyor Medicine\', \'name\': \'Ronald Ross\', \'link\': \'/wiki/Ronald_Ross\'}, {\'year\': \'1902\\n\', \'category\': \'Literature\', \'name\': \'Theodor Mommsen\', \'link\': \'/wiki/Theodor_Mommsen\'}, {\'year\': \'1902\\n\', \'category\': \'Peace\', \'name\': \'\xc3\x89lie Ducommun\', \'link\': \'/wiki/%C3%89lie_Ducommun\'}, {\'year\': \'1902\\n\', \'category\': \'Peace\', \'name\': \'Charles Albert Gobat\', \'link\': \'/wiki/Charles_Albert_Gobat\'}, {\'year\': \'1903\\n\', \'category\': \'Physics\', \'name\': \'Henri Becquerel\', \'link\': \'/wiki/Henri_Becquerel\'}, {\'year\': \'1903\\n\', \'category\': \'Physics\', \'name\': \'Pierre Curie\', \'link\': \'/wiki/Pierre_Curie\'}, {\'year\': \'1903\\n\', \'category\': \'Physics\', \'name\': \'Marie Curie\', \'link\': \'/wiki/Marie_Curie\'}, {\'year\': \'1903\\n\', \'category\': \'Chemistry\', \'name\': \'Svante Arrhenius\', \'link\': \'/wiki/Svante_Arrhenius\'}, {\'year\': \'1903\\n\', \'category\': \'Physiologyor Medicine\', \'name\': \'Niels Ryberg Finsen\', \'link\': \'/wiki/Niels_Ryberg_Finsen\'}, {\'year\': \'1903\\n\', \'category\': \'Literature\', \'name\': \'Bj\xc3\xb8rnstjerne Bj\xc3\xb8rnson\', \'link\': \'/wiki/Bj%C3%B8rnstjerne_Bj%C3%B8rnson\'}, {\'year\': \'1903\\n\', \'category\': \'Peace\', \'name\': \'Randal Cremer\', \'link\': \'/wiki/Randal_Cremer\'}, {\'year\': \'1904\\n\', \'category\': \'Physics\', \'name\': \'Lord Rayleigh\', \'link\': \'/wiki/John_Strutt,_3rd_Baron_Rayleigh\'}, {\'year\': \'1904\\n\', \'category\': \'Chemistry\', \'name\': \'William Ramsay\', \'link\': \'/wiki/William_Ramsay\'}, {\'year\': \'1904\\n\', \'category\': \'Physiologyor Medicine\', \'name\': \'Ivan Pavlov\', \'link\': \'/wiki/Ivan_Pavlov\'}, {\'year\': \'1904\\n\', \'category\': \'Literature\', \'name\': \'Fr\xc3\xa9d\xc3\xa9ric Mistral\', \'link\': \'/wiki/Fr%C3%A9d%C3%A9ric_Mistral\'}, {\'year\': \'1904\\n\', \'category\': \'Literature\', \'name\': \'Jos\xc3\xa9 Echegaray\', \'link\': \'/wiki/Jos%C3%A9_Echegaray\'}, {\'year\': \'1904\\n\', \'category\': \'Peace\', \'name\': \'Institut de Droit International\', \'link\': \'/wiki/Institut_de_Droit_International\'}, {\'year\': \'1905\\n\', \'category\': \'Physics\', \'name\': \'Philipp Lenard\', \'link\': \'/wiki/Philipp_Lenard\'}, {\'year\': \'1905\\n\', \'category\': \'Chemistry\', \'name\': \'Adolf von Baeyer\', \'link\': \'/wiki/Adolf_von_Baeyer\'}, {\'year\': \'1905\\n\', \'category\': \'Physiologyor Medicine\', \'name\': \'Robert Koch\', \'link\': \'/wiki/Robert_Koch\'}, {\'year\': \'1905\\n\', \'category\': \'Literature\', \'name\': \'Henryk Sienkiewicz\', \'link\': \'/wiki/Henryk_Sienkiewicz\'}, {\'year\': \'1905\\n\', \'category\': \'Peace\', \'name\': \'Bertha von Suttner\', \'link\': \'/wiki/Bertha_von_Suttner\'}, {\'y ...
